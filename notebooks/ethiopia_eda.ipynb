# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\yordi\\OneDrive\\Desktop\\weekzeroo\\climate-challenge-week0\\data\\ethiopia.csv")

# Add country column
df["Country"] = "Ethiopia"

df.head()
# Out:
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  11.73    22.75     3.44      19.31          0.0  41.79  2.73
# 1  2015    2  12.30    24.01     4.09      19.92          0.0  33.29  2.39
# 2  2015    3  12.49    24.17     3.97      20.20          0.0  33.83  1.77
# 3  2015    4  14.08    23.78     6.90      16.88          0.0  38.84  0.87
# 4  2015    5  14.06    23.15     7.32      15.83          0.0  47.07  1.34
#
#    WS2M_MAX     PS  QV2M   Country
# 0      5.07  77.13  4.00  Ethiopia
# 1      4.19  77.14  3.35  Ethiopia
# 2      2.76  77.11  3.43  Ethiopia
# 3      1.28  77.07  4.60  Ethiopia
# 4      2.14  77.01  5.58  Ethiopia

# %%
df["Date"] = pd.to_datetime(df["YEAR"] * 1000 + df["DOY"], format="%Y%j")

# Extract Month
df["Month"] = df["Date"].dt.month

# %%
df.replace(-999, np.nan, inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df.drop_duplicates()

# %%
df.describe()
# Out:
#               YEAR          DOY         T2M      T2M_MAX      T2M_MIN  \
# count  4108.000000  4108.000000  4108.00000  4108.000000  4108.000000
# mean   2020.131451   180.121227    16.06850    23.199175    10.227544
# min    2015.000000     1.000000    10.03000    15.650000     1.170000
# 25%    2017.000000    86.000000    14.82000    21.110000     8.417500
# 50%    2020.000000   179.000000    16.04000    22.740000    10.990000
# 75%    2023.000000   272.000000    17.36000    25.170000    12.220000
# max    2026.000000   366.000000    21.53000    30.930000    15.680000
# std       3.248907   106.294767     1.89805     2.751471     2.607256
#
#          T2M_RANGE  PRECTOTCORR         RH2M         WS2M     WS2M_MAX  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.000000
# mean     12.971631     3.633795    68.408588     1.979998     3.575246
# min       3.560000     0.000000    14.420000     0.460000     0.790000
# ...

# %%
missing = df.isna().sum()
percent = (missing / len(df)) * 100

pd.DataFrame({
    "Missing": missing,
    "Percent": percent
})
# Out:
#              Missing  Percent
# YEAR               0      0.0
# DOY                0      0.0
# T2M                0      0.0
# T2M_MAX            0      0.0
# T2M_MIN            0      0.0
# T2M_RANGE          0      0.0
# PRECTOTCORR        0      0.0
# RH2M               0      0.0
# WS2M               0      0.0
# WS2M_MAX           0      0.0
# PS                 0      0.0
# QV2M               0      0.0
# Country            0      0.0
# Date               0      0.0
# Month              0      0.0

# %%
from scipy.stats import zscore

cols = ["T2M", "T2M_MAX", "T2M_MIN", "PRECTOTCORR", "RH2M", "WS2M", "WS2M_MAX"]

z_scores = np.abs(zscore(df[cols], nan_policy='omit'))

outliers = (z_scores > 3).sum()
outliers
# Out:
# 137

# %%
# Drop rows with >30% missing
df = df[df.isna().mean(axis=1) < 0.3]

# Forward fill
df.fillna(method="ffill", inplace=True)
# Out:
# C:\Users\yordi\AppData\Local\Temp\ipykernel_10952\660774383.py:5: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)

# %%
df.to_csv("C:\\Users\\yordi\\OneDrive\\Desktop\\weekzeroo\\climate-challenge-week0\\data\\ethiopia_clean.csv", index=False)

# %%
monthly_temp = df.groupby("Month")["T2M"].mean()

monthly_temp.plot()
plt.title("Monthly Avg Temperature")
plt.show()

# %%
monthly_rain = df.groupby("Month")["PRECTOTCORR"].sum()

monthly_rain.plot(kind="bar")
plt.title("Monthly Rainfall")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.show()

# %%
sns.scatterplot(x="T2M", y="RH2M", data=df)
plt.show()

sns.scatterplot(x="T2M_RANGE", y="WS2M", data=df)
plt.show()

# %%
df["PRECTOTCORR"].hist()
plt.title("Rainfall Distribution")
plt.show()

# %%
np.log1p(df["PRECTOTCORR"]).hist()
# Out:
# <Axes: >

# %%
plt.scatter(df["T2M"], df["RH2M"], s=df["PRECTOTCORR"]*10, alpha=0.5)
plt.xlabel("Temperature")git 
plt.ylabel("Humidity")
plt.title("Bubble Chart")
plt.show()
